# %% [markdown]
# <a href="https://colab.research.google.com/github/owl-d/Basic_DeepLearning/blob/main/Doit_Ch02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hi")
# Out:
# Hi

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.19.5

# %%
arr = np.array([[10,20,30],[40,50,60]])
print(arr)

print(type(arr))

np.sum(arr)
# Out:
# [[10 20 30]
#  [40 50 60]]
# <class 'numpy.ndarray'>
# 210

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5],[1,4,9,16,25])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.scatter([1,2,3,4,5],[1,4,9,16,25])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.scatter(x,y)
plt.show()
